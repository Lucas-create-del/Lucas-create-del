# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-create-del/Lucas-create-del/blob/main/Projeto_Final_BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Projeto:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

numeroAnosExperienciaX = np.array([
    4,2,8,1,10,6,3,12,24,17,5,9,7,13,18,11,6,15,20,12
    ])

salarioAnualEmpregadoY = np.array([
    84000,72000,216000,15840,90000,42000,33600,180000,
    74160,120000,48000,66000,88200,114000,36000,49200,
    57600,105600,60000,168000
    ])

coeficiente_angular, intercepto = np.polyfit(
    numeroAnosExperienciaX, salarioAnualEmpregadoY, 1
    )

print(f"Coeficiente Angular: {coeficiente_angular}\n")

print(f"Intercepto: {intercepto}\n")

y_pred = coeficiente_angular * numeroAnosExperienciaX + intercepto
print(f"Previsão: {y_pred}")

plt.scatter(
    numeroAnosExperienciaX,salarioAnualEmpregadoY,label="Dados originais"
    )

plt.plot(
    numeroAnosExperienciaX,y_pred, color="red", linewidth=2, label = "Linha de Regressão"
    )

plt.xlabel("Salário anual dos empregados (X)")

plt.ylabel("Ano de exeperiência dos empregados (Y)")

plt.legend()

plt.title("\nRegressão Linear Simples com Numpy")

plt.grid(True)

plt.show()


mediaExperiencia = np.mean(numeroAnosExperienciaX)
mediaSalario = np.mean(salarioAnualEmpregadoY)
print(f"\nMédia sobre os anos de experiências dos empregados: {mediaExperiencia}")
print(f"Média sobre os salários anuais dos empregados: {mediaSalario}")

medianaExperiencia = np.median(numeroAnosExperienciaX)
medianaSalario = np.median(salarioAnualEmpregadoY)
print(f"\nMediana sobre os anos de experiências dos empregados: {medianaExperiencia}")
print(f"Mediana sobre os salários anuais dos empregados: {medianaSalario}")

modaExperiencia = stats.mode(numeroAnosExperienciaX)
modaSalario = stats.mode(salarioAnualEmpregadoY)
print(f"\nMode sobre os anos de experiências dos empregados: {modaExperiencia}")
print(f"Mode sobre os salários anuais dos empregados: {modaSalario}")

desvioExperiencia = np.std(numeroAnosExperienciaX)
desvioSalario = np.std(salarioAnualEmpregadoY)
print(f"\nDesvio padrão sobre os anos de experiências dos empregados: {desvioExperiencia}")
print(f"Desvio padrão sobre os salários anuais dos empregados: {desvioSalario}")
# Out:
# Coeficiente Angular: 1680.4863464221633
#
# Intercepto: 68953.06358381505
#
# Previsão: [ 75675.0089695   72314.03627666  82396.95435519  70633.54993024
#   85757.92704804  79035.98166235  73994.52262308  89118.89974088
#  109284.73589795  97521.33147299  77355.49531593  84077.44070161
#   80716.46800877  90799.3860873   99201.81781941  87438.41339446
#   79035.98166235  94160.35878015 102562.79051226  89118.89974088]
# Média sobre os anos de experiências dos empregados: 10.15
# Média sobre os salários anuais dos empregados: 86010.0
#
# Mediana sobre os anos de experiências dos empregados: 9.5
# Mediana sobre os salários anuais dos empregados: 73080.0
#
# Mode sobre os anos de experiências dos empregados: ModeResult(mode=6, count=2)
# Mode sobre os salários anuais dos empregados: ModeResult(mode=15840, count=1)
#
# Desvio padrão sobre os anos de experiências dos empregados: 6.134125854594117
# Desvio padrão sobre os salários anuais dos empregados: 50955.9462673396
